# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sea

# %%
df=pd.read_csv('/content/abcnews-date-text.csv',error_bad_lines=False)

# %%
df.shape
# Out:
# (559787, 2)

# %%
df.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
data_text=df[['headline_text']]

# %%
data_text['index']=data_text.index

# %%
document=data_text

# %%
len(document)
# Out:
# 559787

# %%
document[:5]
# Out:
#                                        headline_text  index
# 0  aba decides against community broadcasting lic...      0
# 1     act fire witnesses must be aware of defamation      1
# 2     a g calls for infrastructure protection summit      2
# 3           air nz staff in aust strike for pay rise      3
# 4      air nz strike to affect australian travellers      4

# %%
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords 
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
nltk.download('stopwords')
stop_word=stopwords.words('english')
stemmer=PorterStemmer()
lemitizer=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
np.random.seed(2018)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def cleaning(text):
  var1=[]
  for word in word_tokenize(text):
    if word not in stop_word:
      var1.append(word)
  var2=[]
  for word in var1:
    var2.append(lemitizer.lemmatize(word))

  return var2

# %%
document['new_headline']=document['headline_text'].apply(lambda x:cleaning(x))

# %%
document.head()
# Out:
#                                        headline_text  ...                                      new_headline
# 0  aba decides against community broadcasting lic...  ...  [aba, decides, community, broadcasting, licence]
# 1     act fire witnesses must be aware of defamation  ...     [act, fire, witness, must, aware, defamation]
# 2     a g calls for infrastructure protection summit  ...     [g, call, infrastructure, protection, summit]
# 3           air nz staff in aust strike for pay rise  ...         [air, nz, staff, aust, strike, pay, rise]
# 4      air nz strike to affect australian travellers  ...  [air, nz, strike, affect, australian, traveller]
#
# [5 rows x 3 columns]

# %%
print(document['headline_text'][0])
print(document['new_headline'][0])
# Out:
# aba decides against community broadcasting licence
# ['aba', 'decides', 'community', 'broadcasting', 'licence']

# %%
document['headline_text'][4311]
# Out:
# 'residents hope rain not so heavy'

# %%
document['new_headline'][4311]
# Out:
# ['resident', 'hope', 'rain', 'heavy']

# %%
df=document.drop('headline_text',axis=1)

# %%
df.head()
# Out:
#    index                                      new_headline
# 0      0  [aba, decides, community, broadcasting, licence]
# 1      1     [act, fire, witness, must, aware, defamation]
# 2      2     [g, call, infrastructure, protection, summit]
# 3      3         [air, nz, staff, aust, strike, pay, rise]
# 4      4  [air, nz, strike, affect, australian, traveller]

# %%
def extra_clean(text):
  var1=[]
  for word in text:
    var1.append(stemmer.stem(word))
  return var1

# %%
df['new_headline']=df['new_headline'].apply(lambda x:extra_clean(x))

# %%
df.head()
# Out:
#    index                                   new_headline
# 0      0        [aba, decid, commun, broadcast, licenc]
# 1      1            [act, fire, wit, must, awar, defam]
# 2      2      [g, call, infrastructur, protect, summit]
# 3      3      [air, nz, staff, aust, strike, pay, rise]
# 4      4  [air, nz, strike, affect, australian, travel]

# %%
processed_docs=df['new_headline']

# %%
processed_docs[:10]
# Out:
# 0              [aba, decid, commun, broadcast, licenc]
# 1                  [act, fire, wit, must, awar, defam]
# 2            [g, call, infrastructur, protect, summit]
# 3            [air, nz, staff, aust, strike, pay, rise]
# 4        [air, nz, strike, affect, australian, travel]
# 5                   [ambiti, olsson, win, tripl, jump]
# 6               [antic, delight, record, break, barca]
# 7    [aussi, qualifi, stosur, wast, four, memphi, m...
# 8            [aust, address, un, secur, council, iraq]
# 9                   [australia, lock, war, timet, opp]
# Name: new_headline, dtype: object

# %%
import gensim
from gensim import corpora

# %%
dictionary=corpora.Dictionary(processed_docs)

# %%
print(dictionary.token2id)
# Out:
# {'aba': 0, 'broadcast': 1, 'commun': 2, 'decid': 3, 'licenc': 4, 'act': 5, 'awar': 6, 'defam': 7, 'fire': 8, 'must': 9, 'wit': 10, 'call': 11, 'g': 12, 'infrastructur': 13, 'protect': 14, 'summit': 15, 'air': 16, 'aust': 17, 'nz': 18, 'pay': 19, 'rise': 20, 'staff': 21, 'strike': 22, 'affect': 23, 'australian': 24, 'travel': 25, 'ambiti': 26, 'jump': 27, 'olsson': 28, 'tripl': 29, 'win': 30, 'antic': 31, 'barca': 32, 'break': 33, 'delight': 34, 'record': 35, 'aussi': 36, 'four': 37, 'match': 38, 'memphi': 39, 'qualifi': 40, 'stosur': 41, 'wast': 42, 'address': 43, 'council': 44, 'iraq': 45, 'secur': 46, 'un': 47, 'australia': 48, 'lock': 49, 'opp': 50, 'timet': 51, 'war': 52, '10': 53, 'aid': 54, 'contribut': 55, 'million': 56, 'birthday': 57, 'celebr': 58, 'robson': 59, 'take': 60, 'ahead': 61, 'bathhous': 62, 'move': 63, 'plan': 64, 'big': 65, 'championship': 66, 'cycl': 67, 'hope': 68, 'launceston': 69, 'boost': 70, 'paroo': 71, 'suppli': 72, 'water': 73, 'bill': 74, 'blizzard': 75, 'buri': 76, 'state': 77, 'unit': 78, 'brigadi': 79, 'dismiss': 80, 'harass': 81, 'report': 82, 'troop': 83, 'arriv': 84, 'british': 85, 'combat': 86, 'daili': 87, 'kuwait': 88, 'bryant': 89, 'doubl': 90, 'laker': 91, 'lead': 92, 'overtim': 93, 'bushfir': 94, 'centrelink': 95, 'see': 96, 'urg': 97, 'victim': 98, 'attack': 99, 'busi': 100, 'prepar': 101, 'terrorist': 102, 'aveng': 103, 'calleri': 104, 'defeat': 105, 'elimin': 106, 'final': 107, 'massu': 108, 'blend': 109, 'ethanol': 110, 'fuel': 111, 'go': 112, 'carew': 113, 'freak': 114, 'goal': 115, 'leaf': 116, 'rom': 117, 'ruin': 118, 'cemeteri': 119, 'fund': 120, 'miss': 121, 'code': 122, 'conduct': 123, 'donat': 124, 'organ': 125, 'regul': 126, 'toughen': 127, 'bank': 128, 'commonwealth': 129, 'cut': 130, 'fix': 131, 'home': 132, 'loan': 133, 'rate': 134, 'help': 135, 'homeless': 136, 'youth': 137, 'chief': 138, 'execut': 139, 'fail': 140, 'posit': 141, 'contest': 142, 'councillor': 143, 'independ': 144, 'wollongong': 145, 'garden': 146, 'heritag': 147, 'ta': 148, 'ambul': 149, 'decis': 150, 'levi': 151, 'welcom': 152, 'breakthrough': 153, 'insur': 154, 'alp': 155, 'crean': 156, 'critic': 157, 'leadership': 158, 'shut': 159, 'tell': 160, 'dargo': 161, 'expect': 162, 'threat': 163, 'climb': 164, 'continu': 165, 'death': 166, 'korean': 167, 'south': 168, 'subway': 169, 'toll': 170, 'conflict': 171, 'dem': 172, 'hold': 173, 'iraqi': 174, 'plebiscit': 175, 'dent': 176, 'down': 177, 'philippoussi': 178, 'thriller': 179, 'tie': 180, '5': 181, 'de': 182, 'fate': 183, 'learn': 184, 'march': 185, 'villier': 186, 'becom': 187, 'commonplac': 188, 'digit': 189, 'tv': 190, 'anger': 191, 'direct': 192, 'govt': 193, 'soldier': 194, 'disput': 195, 'plant': 196, 'process': 197, 'smithton': 198, 'veget': 199, '18': 200, 'dog': 201, 'maul': 202, 'month': 203, 'nsw': 204, 'old': 205, 'toddler': 206, 'die': 207, 'passeng': 208, 'phone': 209, 'chang': 210, 'england': 211, 'three': 212, 'wale': 213, 'chemic': 214, 'clean': 215, 'cost': 216, 'epa': 217, 'recov': 218, 'still': 219, 'tri': 220, 'build': 221, 'express': 222, 'interest': 223, 'livestock': 224, 'sought': 225, 'fed': 226, 'introduc': 227, 'nation': 228, 'acid': 229, 'contain': 230, 'firefight': 231, 'spill': 232, 'crash': 233, 'head': 234, 'highway': 235, 'injur': 236, 'freedom': 237, 'net': 238, 'profit': 239, 'success': 240, 'third': 241, 'alloc': 242, 'domest': 243, 'violenc': 244, 'risk': 245, 'announc': 246, 'bridg': 247, 'work': 248, 'cadel': 249, 'upgrad': 250, 'cossack': 251, 'restor': 252, '11': 253, 'accus': 254, 'court': 255, 'german': 256, 'give': 257, 'sept': 258, 'verdict': 259, 'back': 260, 'gilchrist': 261, 'polici': 262, 'rest': 263, 'girl': 264, 'bilbi': 265, 'coast': 266, 'gold': 267, 'hear': 268, 'project': 269, 'ban': 270, 'club': 271, 'feel': 272, 'golf': 273, 'impact': 274, 'smoke': 275, 'blame': 276, 'unpopular': 277, 'altern': 278, 'green': 279, 'offer': 280, 'polic': 281, 'station': 282, 'griffith': 283, 'knock': 284, 'art': 285 ...

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 aba
# 1 broadcast
# 2 commun
# 3 decid
# 4 licenc
# 5 act
# 6 awar
# 7 defam
# 8 fire
# 9 must
# 10 wit

# %%
dictionary.filter_extremes(no_below=15,no_above=0.5,keep_n=100000)

# %%
my_corpus=[]
for word in processed_docs:
  my_corpus.append(dictionary.doc2bow(word))

# %%
var1=[]
for doc in my_corpus:
  for key,freq in doc:
    var1.append([dictionary[key],freq])

# %%
from gensim import models

# %%
tfidf=models.TfidfModel(my_corpus)

# %%
corpus_tfidf=tfidf[my_corpus]

# %%
from gensim.models import LdaModel,LdaMulticore

# %%
lda_model=LdaMulticore(my_corpus,num_topics=15,id2word=dictionary,passes=2,workers=2)

# %%
print(lda_model)
# Out:
# LdaModel(num_terms=10513, num_topics=15, decay=0.5, chunksize=2000)

# %%
for idx,topic in lda_model.print_topics(-1):
  print('topic :{} \nwords :{}'.format(idx,topic))
# Out:
# topic :0
# words :0.032*"talk" + 0.021*"rudd" + 0.018*"deni" + 0.018*"protest" + 0.017*"north" + 0.016*"leader" + 0.015*"south" + 0.014*"pm" + 0.013*"minist" + 0.013*"asylum"
# topic :1
# words :0.028*"govt" + 0.027*"plan" + 0.023*"fund" + 0.022*"health" + 0.019*"mine" + 0.016*"school" + 0.014*"boost" + 0.013*"urg" + 0.013*"nsw" + 0.013*"council"
# topic :2
# words :0.029*"win" + 0.023*"home" + 0.020*"open" + 0.019*"day" + 0.019*"set" + 0.018*"australia" + 0.015*"aussi" + 0.015*"final" + 0.015*"lead" + 0.015*"first"
# topic :3
# words :0.062*"polic" + 0.022*"probe" + 0.018*"investig" + 0.017*"victim" + 0.014*"speak" + 0.013*"bodi" + 0.013*"fire" + 0.013*"look" + 0.013*"dog" + 0.012*"black"
# topic :4
# words :0.039*"water" + 0.024*"ban" + 0.023*"hope" + 0.022*"time" + 0.020*"farmer" + 0.015*"rain" + 0.012*"decis" + 0.011*"use" + 0.011*"offer" + 0.010*"good"
# topic :5
# words :0.016*"bail" + 0.016*"show" + 0.012*"expert" + 0.012*"near" + 0.012*"poll" + 0.011*"citi" + 0.011*"whale" + 0.010*"hunt" + 0.010*"town" + 0.010*"grant"
# topic :6
# words :0.063*"man" + 0.042*"charg" + 0.033*"court" + 0.031*"polic" + 0.026*"face" + 0.023*"woman" + 0.023*"jail" + 0.023*"accus" + 0.022*"murder" + 0.020*"miss"
# topic :7
# words :0.037*"council" + 0.030*"chang" + 0.024*"elect" + 0.018*"law" + 0.018*"govern" + 0.018*"union" + 0.017*"hous" + 0.017*"seek" + 0.016*"blaze" + 0.014*"vote"
# topic :8
# words :0.038*"u" + 0.028*"attack" + 0.022*"australian" + 0.021*"dead" + 0.020*"kill" + 0.020*"death" + 0.015*"pakistan" + 0.013*"blast" + 0.013*"bomb" + 0.012*"v"
# topic :9
# words :0.031*"claim" + 0.028*"return" + 0.016*"reject" + 0.014*"warn" + 0.014*"life" + 0.013*"link" + 0.013*"studi" + 0.013*"record" + 0.012*"reveal" + 0.012*"victori"
# topic :10
# words :0.111*"interview" + 0.026*"kill" + 0.026*"crash" + 0.025*"year" + 0.022*"sydney" + 0.018*"two" + 0.015*"abc" + 0.015*"flood" + 0.013*"injur" + 0.012*"three"
# topic :11
# words :0.031*"fear" + 0.026*"power" + 0.024*"test" + 0.020*"pay" + 0.016*"forc" + 0.016*"flu" + 0.015*"strike" + 0.015*"futur" + 0.014*"sign" + 0.014*"air"
# topic :12
# words :0.030*"child" + 0.028*"job" + 0.023*"sa" + 0.018*"busi" + 0.017*"bushfir" + 0.014*"cut" + 0.013*"premier" + 0.013*"save" + 0.011*"risk" + 0.011*"public"
# topic :13
# words :0.035*"green" + 0.017*"concern" + 0.015*"safeti" + 0.014*"sale" + 0.013*"rescu" + 0.012*"oil" + 0.012*"price" + 0.011*"compani" + 0.011*"light" + 0.011*"question"
# topic :14
# words :0.031*"rise" + 0.023*"rate" + 0.022*"market" + 0.019*"fall" + 0.018*"coast" + 0.017*"gold" + 0.017*"big" + 0.016*"share" + 0.015*"gillard" + 0.013*"liber"

# %%
processed_docs[4310]
# Out:
# ['ratepay', 'group', 'want', 'compulsori', 'local', 'govt', 'vote']

# %%
for index, score in sorted(lda_model[my_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.4702596366405487
# Topic: 0.028*"govt" + 0.027*"plan" + 0.023*"fund" + 0.022*"health" + 0.019*"mine" + 0.016*"school" + 0.014*"boost" + 0.013*"urg" + 0.013*"nsw" + 0.013*"council"
#
# Score: 0.155799999833107
# Topic: 0.037*"council" + 0.030*"chang" + 0.024*"elect" + 0.018*"law" + 0.018*"govern" + 0.018*"union" + 0.017*"hous" + 0.017*"seek" + 0.016*"blaze" + 0.014*"vote"
#
# Score: 0.147896870970726
# Topic: 0.035*"green" + 0.017*"concern" + 0.015*"safeti" + 0.014*"sale" + 0.013*"rescu" + 0.012*"oil" + 0.012*"price" + 0.011*"compani" + 0.011*"light" + 0.011*"question"
#
# Score: 0.13437682390213013
# Topic: 0.039*"water" + 0.024*"ban" + 0.023*"hope" + 0.022*"time" + 0.020*"farmer" + 0.015*"rain" + 0.012*"decis" + 0.011*"use" + 0.011*"offer" + 0.010*"good"

# %%
print(dictionary.token2id)
# Out:
# {'aba': 0, 'broadcast': 1, 'commun': 2, 'decid': 3, 'licenc': 4, 'act': 5, 'awar': 6, 'defam': 7, 'fire': 8, 'must': 9, 'wit': 10, 'call': 11, 'g': 12, 'infrastructur': 13, 'protect': 14, 'summit': 15, 'air': 16, 'aust': 17, 'nz': 18, 'pay': 19, 'rise': 20, 'staff': 21, 'strike': 22, 'affect': 23, 'australian': 24, 'travel': 25, 'ambiti': 26, 'jump': 27, 'tripl': 28, 'win': 29, 'antic': 30, 'barca': 31, 'break': 32, 'delight': 33, 'record': 34, 'aussi': 35, 'four': 36, 'match': 37, 'memphi': 38, 'qualifi': 39, 'stosur': 40, 'wast': 41, 'address': 42, 'council': 43, 'iraq': 44, 'secur': 45, 'un': 46, 'australia': 47, 'lock': 48, 'opp': 49, 'timet': 50, 'war': 51, '10': 52, 'aid': 53, 'contribut': 54, 'million': 55, 'birthday': 56, 'celebr': 57, 'robson': 58, 'take': 59, 'ahead': 60, 'bathhous': 61, 'move': 62, 'plan': 63, 'big': 64, 'championship': 65, 'cycl': 66, 'hope': 67, 'launceston': 68, 'boost': 69, 'paroo': 70, 'suppli': 71, 'water': 72, 'bill': 73, 'blizzard': 74, 'buri': 75, 'state': 76, 'unit': 77, 'dismiss': 78, 'harass': 79, 'report': 80, 'troop': 81, 'arriv': 82, 'british': 83, 'combat': 84, 'daili': 85, 'kuwait': 86, 'bryant': 87, 'doubl': 88, 'laker': 89, 'lead': 90, 'overtim': 91, 'bushfir': 92, 'centrelink': 93, 'see': 94, 'urg': 95, 'victim': 96, 'attack': 97, 'busi': 98, 'prepar': 99, 'terrorist': 100, 'aveng': 101, 'defeat': 102, 'elimin': 103, 'final': 104, 'blend': 105, 'ethanol': 106, 'fuel': 107, 'go': 108, 'freak': 109, 'goal': 110, 'leaf': 111, 'rom': 112, 'ruin': 113, 'cemeteri': 114, 'fund': 115, 'miss': 116, 'code': 117, 'conduct': 118, 'donat': 119, 'organ': 120, 'regul': 121, 'toughen': 122, 'bank': 123, 'commonwealth': 124, 'cut': 125, 'fix': 126, 'home': 127, 'loan': 128, 'rate': 129, 'help': 130, 'homeless': 131, 'youth': 132, 'chief': 133, 'execut': 134, 'fail': 135, 'posit': 136, 'contest': 137, 'councillor': 138, 'independ': 139, 'wollongong': 140, 'garden': 141, 'heritag': 142, 'ta': 143, 'ambul': 144, 'decis': 145, 'levi': 146, 'welcom': 147, 'breakthrough': 148, 'insur': 149, 'alp': 150, 'crean': 151, 'critic': 152, 'leadership': 153, 'shut': 154, 'tell': 155, 'expect': 156, 'threat': 157, 'climb': 158, 'continu': 159, 'death': 160, 'korean': 161, 'south': 162, 'subway': 163, 'toll': 164, 'conflict': 165, 'dem': 166, 'hold': 167, 'iraqi': 168, 'dent': 169, 'down': 170, 'philippoussi': 171, 'thriller': 172, 'tie': 173, '5': 174, 'de': 175, 'fate': 176, 'learn': 177, 'march': 178, 'villier': 179, 'becom': 180, 'digit': 181, 'tv': 182, 'anger': 183, 'direct': 184, 'govt': 185, 'soldier': 186, 'disput': 187, 'plant': 188, 'process': 189, 'veget': 190, '18': 191, 'dog': 192, 'maul': 193, 'month': 194, 'nsw': 195, 'old': 196, 'toddler': 197, 'die': 198, 'passeng': 199, 'phone': 200, 'chang': 201, 'england': 202, 'three': 203, 'wale': 204, 'chemic': 205, 'clean': 206, 'cost': 207, 'epa': 208, 'recov': 209, 'still': 210, 'tri': 211, 'build': 212, 'express': 213, 'interest': 214, 'livestock': 215, 'sought': 216, 'fed': 217, 'introduc': 218, 'nation': 219, 'acid': 220, 'contain': 221, 'firefight': 222, 'spill': 223, 'crash': 224, 'head': 225, 'highway': 226, 'injur': 227, 'freedom': 228, 'net': 229, 'profit': 230, 'success': 231, 'third': 232, 'alloc': 233, 'domest': 234, 'violenc': 235, 'risk': 236, 'announc': 237, 'bridg': 238, 'work': 239, 'cadel': 240, 'upgrad': 241, 'restor': 242, '11': 243, 'accus': 244, 'court': 245, 'german': 246, 'give': 247, 'sept': 248, 'verdict': 249, 'back': 250, 'gilchrist': 251, 'polici': 252, 'rest': 253, 'girl': 254, 'bilbi': 255, 'coast': 256, 'gold': 257, 'hear': 258, 'project': 259, 'ban': 260, 'club': 261, 'feel': 262, 'golf': 263, 'impact': 264, 'smoke': 265, 'blame': 266, 'unpopular': 267, 'altern': 268, 'green': 269, 'offer': 270, 'polic': 271, 'station': 272, 'griffith': 273, 'knock': 274, 'art': 275, 'group': 276, 'meet': 277, 'north': 278, 'rock': 279, 'wa': 280, 'west': 281, 'access': 282, 'card': 283, 'credit': 284, 'eight': 285, 'gain': 286, 'hacker': ...

# %%
len(dictionary)
# Out:
# 10513
